# %%
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()
import datetime
import numpy as np

# %%
listings_file = "Resources/listings.csv"
listings_data = pd.read_csv(listings_file)
listings_data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
listings_data.head()
# Out:
#      id                                               name  host_id  \
# 0   958                Bright, Modern Garden Unit - 1BR/1B     1169
# 1  5858                                 Creative Sanctuary     8904
# 2  7918         A Friendly Room - UCSF/USF - San Francisco    21994
# 3  8142  Friendly Room Apt. Style -UCSF/USF - San Franc...    21994
# 4  8339                    Historic Alamo Square Victorian    24215
#
#           host_name  neighbourhood_group     neighbourhood   latitude  \
# 0             Holly                  NaN  Western Addition  37.769310
# 1  Philip And Tania                  NaN    Bernal Heights  37.745112
# 2             Aaron                  NaN    Haight Ashbury  37.766690
# 3             Aaron                  NaN    Haight Ashbury  37.764872
# 4              Rosy                  NaN  Western Addition  37.775249
#
#     longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0 -122.433856  Entire home/apt    170               1                156
# 1 -122.421018  Entire home/apt    235              30                112
# 2 -122.452505     Private room     65              32                 17
# 3 -122.451828     Private room     65              32                  7
# 4 -122.436374  Entire home/apt    675               7                 27
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0   8/19/2018               1.40                               1
# 1    8/6/2017               0.98                               1
# 2  11/21/2016               0.15                               9
# 3   8/12/2017               0.14                               9
# 4   8/11/2018               0.25                               2
#
#    availability_365
# 0               119
# 1               365
# 2               365
# 3               361
# 4                82

# %%
new_listings_df = listings_data[['name', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'number_of_reviews']]
new_listings_df.head()
# Out:
#                                                 name     neighbourhood  \
# 0                Bright, Modern Garden Unit - 1BR/1B  Western Addition
# 1                                 Creative Sanctuary    Bernal Heights
# 2         A Friendly Room - UCSF/USF - San Francisco    Haight Ashbury
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...    Haight Ashbury
# 4                    Historic Alamo Square Victorian  Western Addition
#
#     latitude   longitude        room_type  price  number_of_reviews
# 0  37.769310 -122.433856  Entire home/apt    170                156
# 1  37.745112 -122.421018  Entire home/apt    235                112
# 2  37.766690 -122.452505     Private room     65                 17
# 3  37.764872 -122.451828     Private room     65                  7
# 4  37.775249 -122.436374  Entire home/apt    675                 27

# %%
new_list_df = new_listings_df.dropna()
new_list_df.count()
# Out:
# name                 6529
# neighbourhood        6529
# latitude             6529
# longitude            6529
# room_type            6529
# price                6529
# number_of_reviews    6529
# dtype: int64

# %%
new_list_df = new_list_df.rename(columns={'name': 'Name', 'neighbourhood': 'Neighborhood', 'latitude': 'Latitude', 'longitude': 'Longitude', 'room_type': 'Room Type', 'price': 'Price', 'number_of_reviews': 'Number of Reviews' })
new_list_df.head()
# Out:
#                                                 Name      Neighborhood  \
# 0                Bright, Modern Garden Unit - 1BR/1B  Western Addition
# 1                                 Creative Sanctuary    Bernal Heights
# 2         A Friendly Room - UCSF/USF - San Francisco    Haight Ashbury
# 3  Friendly Room Apt. Style -UCSF/USF - San Franc...    Haight Ashbury
# 4                    Historic Alamo Square Victorian  Western Addition
#
#     Latitude   Longitude        Room Type  Price  Number of Reviews
# 0  37.769310 -122.433856  Entire home/apt    170                156
# 1  37.745112 -122.421018  Entire home/apt    235                112
# 2  37.766690 -122.452505     Private room     65                 17
# 3  37.764872 -122.451828     Private room     65                  7
# 4  37.775249 -122.436374  Entire home/apt    675                 27

# %%
crime_file = "Resources/sf_crime.csv"
crime_db = pd.read_csv(crime_file)
crime_db.head()
# Out:
#   Incident Datetime Incident Date Incident Time  Incident Year  \
# 0     1/1/2018 1:30      1/1/2018          1:30           2018
# 1     1/1/2018 1:59      1/1/2018          1:59           2018
# 2     1/1/2018 2:28      1/1/2018          2:28           2018
# 3     1/1/2018 2:28      1/1/2018          2:28           2018
# 4     1/1/2018 2:08      1/1/2018          2:08           2018
#
#   Incident Day of Week Report Datetime       Row ID  Incident ID  \
# 0               Monday   1/1/2018 2:13  61870203073       618702
# 1               Monday   1/1/2018 1:59  61870768000       618707
# 2               Monday   1/1/2018 2:31  61870904134       618709
# 3               Monday   1/1/2018 2:31  61870928160       618709
# 4               Monday   1/1/2018 2:08  61871004014       618710
#
#    Incident Number   CAD Number                    ...                      \
# 0        180000263  180010563.0                    ...
# 1        180000326  180010504.0                    ...
# 2        180000348  180010636.0                    ...
# 3        180000348  180010636.0                    ...
# 4        180000285  180010537.0                    ...
#
#                        Incident Description            Resolution  \
# 0                  Robbery, W/ Other Weapon        Open or Active
# 1                               Fire Report        Open or Active
# 2                                   Battery        Open or Active
# 3  Malicious Mischief, Vandalism to Vehicle        Open or Active
# 4             Assault, Aggravated, W/ Force  Cite or Arrest Adult
#
#                              Intersection         CNN Police District  \
# 0                 JUSTIN DR \ COLLEGE AVE  21236000.0       Ingleside
# 1                    16TH ST \ MISSION ST  24170000.0         Mission
# 2                      03RD ST \ PERRY ST  20657000.0        Southern
# 3                      03RD ST \ PERRY ST  20657000.0        Southern
# 4  CESAR CHAVEZ ST \ CAPP ST \ MISSION ST  21304000.0         Mission
#
#   Analysis Neighborhood Supervisor District   Latitude   Longitude  \
# 0        Bernal Heights                 9.0  37.732261 -122.423486
# 1               Mission                 9.0  37.765051 -122.419669
# 2       South of Market                 6.0  37.782119 -122.396841
# 3       South of Market                 6.0  37.782119 -122.396841
# 4        Bernal Heights                 9.0  37.748166 -122.418221
#
#                                        point
# 0  (37.732261252752224, -122.42348641495892)
# 1   (37.76505133632968, -122.41966897380142)
# 2   (37.78211912156566, -122.39684142850209)
# 3   (37.78211912156566, -122.39684142850209)
# 4   (37.74816568813204, -122.41822117169174)
#
# [5 rows x 26 columns]

# %%
crime = crime_db[['Incident Date', 'Incident Year', 'Analysis Neighborhood', 'Incident Description', 'Latitude', 'Longitude']]
crime.count()
# Out:
# Incident Date            111531
# Incident Year            111531
# Analysis Neighborhood    105913
# Incident Description     111531
# Latitude                 105956
# Longitude                105956
# dtype: int64

# %%
crime = crime.dropna()
crime.count()
# Out:
# Incident Date            105913
# Incident Year            105913
# Analysis Neighborhood    105913
# Incident Description     105913
# Latitude                 105913
# Longitude                105913
# dtype: int64

# %%
crime.head()
# Out:
#   Incident Date  Incident Year Analysis Neighborhood  \
# 0      1/1/2018           2018        Bernal Heights
# 1      1/1/2018           2018               Mission
# 2      1/1/2018           2018       South of Market
# 3      1/1/2018           2018       South of Market
# 4      1/1/2018           2018        Bernal Heights
#
#                        Incident Description   Latitude   Longitude
# 0                  Robbery, W/ Other Weapon  37.732261 -122.423486
# 1                               Fire Report  37.765051 -122.419669
# 2                                   Battery  37.782119 -122.396841
# 3  Malicious Mischief, Vandalism to Vehicle  37.782119 -122.396841
# 4             Assault, Aggravated, W/ Force  37.748166 -122.418221

# %%
crime = crime.rename(columns={'Analysis Neighborhood': 'Neighborhood'})
crime.head()
# Out:
#   Incident Date  Incident Year     Neighborhood  \
# 0      1/1/2018           2018   Bernal Heights
# 1      1/1/2018           2018          Mission
# 2      1/1/2018           2018  South of Market
# 3      1/1/2018           2018  South of Market
# 4      1/1/2018           2018   Bernal Heights
#
#                        Incident Description   Latitude   Longitude
# 0                  Robbery, W/ Other Weapon  37.732261 -122.423486
# 1                               Fire Report  37.765051 -122.419669
# 2                                   Battery  37.782119 -122.396841
# 3  Malicious Mischief, Vandalism to Vehicle  37.782119 -122.396841
# 4             Assault, Aggravated, W/ Force  37.748166 -122.418221

# %% [markdown]
# ## Price vs. Number of Crimes in the Neighborhood

# %%
grouped_by_neighborhood = crime.groupby(['Neighborhood'])
grouped_by_neighborhood.head()
# Out:
#      Incident Date  Incident Year                    Neighborhood  \
# 0         1/1/2018           2018                  Bernal Heights
# 1         1/1/2018           2018                         Mission
# 2         1/1/2018           2018                 South of Market
# 3         1/1/2018           2018                 South of Market
# 4         1/1/2018           2018                  Bernal Heights
# 5         1/1/2018           2018                  Bernal Heights
# 6         1/1/2018           2018                  Bernal Heights
# 7         1/1/2018           2018                      Tenderloin
# 8         1/1/2018           2018                 South of Market
# 9         1/1/2018           2018                      Tenderloin
# 10        1/1/2018           2018                      Tenderloin
# 11        1/1/2018           2018                       Excelsior
# 12        1/1/2018           2018                         Mission
# 13        1/1/2018           2018                         Mission
# 14        1/1/2018           2018                 South of Market
# 15        1/1/2018           2018                 South of Market
# 16        1/1/2018           2018                   Outer Mission
# 17        1/1/2018           2018      Oceanview/Merced/Ingleside
# 18        1/1/2018           2018  Financial District/South Beach
# 19        1/1/2018           2018               Lone Mountain/USF
# 20        1/1/2018           2018                         Mission
# 21        1/1/2018           2018  Financial District/South Beach
# 22        1/1/2018           2018  Financial District/South Beach
# 23        1/1/2018           2018  Financial District/South Beach
# 24        1/1/2018           2018           Bayview Hunters Point
# 25        1/1/2018           2018                        Nob Hill
# 26        1/1/2018           2018           Bayview Hunters Point
# 27        1/1/2018           2018      Oceanview/Merced/Ingleside
# 28        1/1/2018           2018      Oceanview/Merced/Ingleside
# 29        1/1/2018           2018                      Tenderloin
# ...            ...            ...                             ...
# 725       1/2/2018           2018                       Glen Park
# 855       1/3/2018           2018                 Treasure Island
# 908       1/2/2018           2018                        Presidio
# 916       1/4/2018           2018                        Presidio
# 918       1/4/2018           2018                        Seacliff
# 1137      1/5/2018           2018                      Noe Valley
# 1215      1/5/2018           2018                        Seacliff
# 1229      1/5/2018           2018                        Presidio
# 1352      1/6/2018           2018                    Lincoln Park
# 1382      1/1/2018           2018                       Glen Park
# 1414      1/1/2018           2018                    Lincoln Park
# 1463      1/5/2018           2018                 Treasure Island
# 1600      1/6/2018           2018                      Twin Peaks
# 1666      1/6/2018           2018                    Lincoln Park
# 1667      1/6/2018           2018                    Lincoln Park
# 1668      1/6/2018           2018                    Lincoln Park
# 1672      1/6/2018           2018                      Twin Peaks
# 1814      1/6/2018           2018                      Twin Peaks
# 1895      1/7/2018           2018                      Twin Peaks
# 1938      1/7/2018           2018                       Glen Park
# 2300      1/8/2018           2018                      Twin Peaks
# 2567      1/9/2018           2018                 Treasure Island
# 2648      1/7/2018           2018                        Seacliff
# 3314     1/11/2018           2018                        Seacliff
# 4460     1/13/2018           2018                    McLaren Park
# 4579     1/14/2018           2018                 Treasure Island
# 6027     1/18/2018           2018                    McLaren Park
# 6203     1/18/2018           2018                    McLaren Park
# 7327     1/12/2018           2018                    McLaren Park
# 8388     1/18/2018           2018                    McLaren Park
#
#                                    Incident Description   Latitude   Longitude
# 0                              Robbery, W/ Other Weapon  37.732261 -122.423486
# 1                                           Fire Report  37.765051 -122.419669
# 2                                               Battery  37.782119 -122.396841
# 3              Malicious Mischief, Vandalism to Vehicle  37.782119 -122.396841
# 4                         Assault, Aggravated, W/ Force  37.748166 -122.418221
# 5                          Battery, Of A Police Officer  37.748166 -122.418221
# 6                 Burglary, Vehicle, Att. (Arrest made)  37.748166 -122.418221
# 7                         Assault, Aggravated, W/ Force  37.777723 -122.416401
# 8                                            Aided Case  37.777372 -122.399763
# 9                               Mental Health Detention  37.786659 -122.409775
# 10                                           Aided Case  37.779992 -122.413487
# 11                          Miscellaneous Investigation  37.725871 -122.432857
# 12          Alcohol, Under Influence Of In Public Place  37.763429 -122.419513
# 13      Warrant Arrest, Enroute To Outside Jurisdiction  37.763429 -122.419513
# 14                                              Battery  37.779459 -122.402377
# 15    Theft, From Person, $200-$950 (other than Pick...  37.779459 -122.402377
# 16                              Mental Health Detention  37.733393 -122.429422
# 17                              Mental Health Detention  37.714884 -122.462608
# 18                          Assault, Aggravated, W/ Gun  37.787036 -122.397932
# 19        Battery, former Spouse or Dating Relationship  37.780882 -122.448791
# 20                          Assault, Aggravated, W/ Gun  37.763496 -122.418484
# 21                          Assault, Aggravated, W/ Gun  37.785542 -122.396705
# 22                        Firearm, Possession of Loaded  37.785542 -122.396705
# 23       Firearm, Loaded, in Vehicle, Possession or Use  37.785542 -122.396705
# 24                             Vehicle, Recovered, Auto  37.726222 -122.392235
# 25                                      Found  Property  37.792971 -122.409361
# 26                             Vehicle, Recovered, Auto  37.725736 -122.381377
# 27                                          Trespassing  37.720151 -122.449279
# 28                 Malicious Mischief, Breaking Windows  37.720151 -122.449279
# 29            Burglary, Apartment House, Unlawful Entry  37.784866 -122.412782
# ...                                                 ...        ...         ...
# 725                                   Suspicious Person  37.737789 -122.439920
# 855                                             Battery  37.829549 -122.371429
# 908                                   Robbery, W/ Force  37.804642 -122.471124
# 916                               Suspicious Occurrence  37.799488 -122.459577
# 918                            Vehicle, Recovered, Auto  37.786031 -122.478714
# 1137                                            Battery  37.753292 -122.427583
# 1215  Fraudulent Game or Trick, Obtaining Money or P...  37.783591 -122.491436
# 1229                                      Missing Adult  37.806894 -122.476021
# 1352                     Vehicle, Recovered, Motorcycle  37.781577 -122.494520
# 1382                  Theft, From Locked Vehicle, >$950  37.740081 -122.433711
# 1414                  Theft, From Locked Vehicle, >$950  37.781327 -122.499871
# 1463                              Vehicle, Stolen, Auto  37.826182 -122.374480
# 1600              Vehicle, Recovered, Stolen outside SF  37.752352 -122.445984
# 1666                            Methamphetamine Offense  37.781577 -122.494520
# 1667             Narcotics Paraphernalia, Possession of  37.781577 -122.494520
# 1668                   Warrant Arrest, Local SF Warrant  37.781577 -122.494520
# 1672                  Theft, From Locked Vehicle, >$950  37.752352 -122.445984
# 1814                        Death Report, Cause Unknown  37.751244 -122.451588
# 1895               Theft, From Locked Vehicle, $50-$200  37.752352 -122.445984
# 1938                        Miscellaneous Investigation  37.734797 -122.435550
# 2300                            Mental Health Detention  37.752576 -122.445457
# 2567              Theft, From Locked Vehicle, $200-$950  37.817824 -122.371246
# 2648                        Theft, From Building, >$950  37.785746 -122.485148
# 3314                           Vehicle, Recovered, Auto  37.785884 -122.481929
# 4460     False Personation to Receive Money or Property  37.721809 -122.416484
# 4579                                   Missing Juvenile  37.817824 -122.371246
# 6027              Vehicle, Recovered, Stolen outside SF  37.719332 -122.410002
# 6203                Evading a Police Officer Recklessly  37.718127 -122.414176
# 7327                  Theft, From Locked Vehicle, >$950  37.719587 -122.409022
# 8388               Malicious Mischief, Breaking Windows  37.719587 -122.409022
#
# [205 rows x 6 columns]

# %%
number_of_crimes = grouped_by_neighborhood['Incident Description'].count()
number_of_crimes_db = pd.DataFrame(number_of_crimes)
number_of_crimes_db = number_of_crimes_db.rename(columns={'Incident Description': 'Number of Crimes'}) 
number_of_crimes_db.head()
# Out:
#                        Number of Crimes
# Neighborhood
# Bayview Hunters Point              6008
# Bernal Heights                     1819
# Castro/Upper Market                3352
# Chinatown                          2069
# Excelsior                          1807

# %%
price_by_neighborhood = new_list_df.groupby(['Neighborhood'])
avg_price_by_neighborhood = price_by_neighborhood['Price'].median()
avg_price_by_neighborhood = pd.DataFrame(avg_price_by_neighborhood)
avg_price_by_neighborhood.head()
# Out:
#                      Price
# Neighborhood
# Bayview               99.5
# Bernal Heights       142.0
# Castro/Upper Market  180.0
# Chinatown            140.0
# Crocker Amazon        92.5

# %%
price_vs_crimes = number_of_crimes_db.merge(avg_price_by_neighborhood, how='outer', left_index=True, right_index=True)
price_vs_crimes = price_vs_crimes.dropna()  
price_vs_crimes_df = price_vs_crimes.reset_index()

price_vs_crimes_df['id'] = price_vs_crimes_df.index + 1
price_vs_crimes_df.head()
# Out:
#           Neighborhood  Number of Crimes  Price  id
# 0       Bernal Heights            1819.0  142.0   1
# 1  Castro/Upper Market            3352.0  180.0   2
# 2            Chinatown            2069.0  140.0   3
# 3            Excelsior            1807.0  100.0   4
# 4            Glen Park             524.0  174.0   5

# %% [markdown]
# ## Type of Incidents by Neighborhoods

# %%
grouped_by_descriptions = crime.groupby(['Incident Description','Neighborhood']).count()

grouped_by_descriptions = grouped_by_descriptions.rename(columns={'Incident Date': 'Number of Crimes'}) 
grouped_by_descriptions_db = grouped_by_descriptions[['Number of Crimes']]
df_crime = grouped_by_descriptions_db.reset_index()

df_crime['id'] = df_crime.index + 1

df_crime.head()
# Out:
#                       Incident Description                    Neighborhood  \
# 0  ATM-related Crime (secondary code only)                       Chinatown
# 1  ATM-related Crime (secondary code only)  Financial District/South Beach
# 2  ATM-related Crime (secondary code only)               Lone Mountain/USF
# 3  ATM-related Crime (secondary code only)                          Marina
# 4  ATM-related Crime (secondary code only)                     Mission Bay
#
#    Number of Crimes  id
# 0                 2   1
# 1                 2   2
# 2                 1   3
# 3                 1   4
# 4                 1   5

# %% [markdown]
# ## Price vs. Neighborhood

# %%
price_by_neighborhood = new_list_df.groupby(['Neighborhood','Room Type'])

hood_df = price_by_neighborhood.mean()
price_vs_neighborhood = hood_df[['Price', 'Number of Reviews']] 
price_vs_neighborhood_df = price_vs_neighborhood.reset_index()


price_vs_neighborhood_df['id'] = price_vs_neighborhood_df.index + 1
price_vs_neighborhood_df.head()
# Out:
#      Neighborhood        Room Type       Price  Number of Reviews  id
# 0         Bayview  Entire home/apt  161.660000          49.540000   1
# 1         Bayview     Private room  115.202899          55.826087   2
# 2         Bayview      Shared room   52.000000          92.000000   3
# 3  Bernal Heights  Entire home/apt  215.365639          42.942731   4
# 4  Bernal Heights     Private room  106.030534          65.641221   5

# %% [markdown]
# ## Price vs. Type of Listing (entire home, private room & shared room)

# %%
price_by_roomtype = new_list_df.groupby(['Room Type'])
room_df = price_by_roomtype.mean()
price_vs_room = room_df[['Price', 'Number of Reviews']]
price_vs_room_df = price_vs_room.reset_index()
price_vs_room_df['id'] = price_vs_room_df.index + 1
price_vs_room_df.head()
# Out:
#          Room Type       Price  Number of Reviews  id
# 0  Entire home/apt  268.743564          36.248864   1
# 1     Private room  132.618136          53.946755   2
# 2      Shared room   69.607362          44.656442   3

# %% [markdown]
# ## Crime Rate by Month

# %%
number_crimes = crime.copy()

# %%
number_crimes['Month'] = pd.DatetimeIndex(number_crimes['Incident Date']).month
number_crimes.head()
# Out:
#   Incident Date  Incident Year     Neighborhood  \
# 0      1/1/2018           2018   Bernal Heights
# 1      1/1/2018           2018          Mission
# 2      1/1/2018           2018  South of Market
# 3      1/1/2018           2018  South of Market
# 4      1/1/2018           2018   Bernal Heights
#
#                        Incident Description   Latitude   Longitude  Month
# 0                  Robbery, W/ Other Weapon  37.732261 -122.423486      1
# 1                               Fire Report  37.765051 -122.419669      1
# 2                                   Battery  37.782119 -122.396841      1
# 3  Malicious Mischief, Vandalism to Vehicle  37.782119 -122.396841      1
# 4             Assault, Aggravated, W/ Force  37.748166 -122.418221      1

# %%
number_crimes= number_crimes.groupby("Month").count()
number_crimes.head()
# Out:
#        Incident Date  Incident Year  Neighborhood  Incident Description  \
# Month
# 1              12420          12420         12420                 12420
# 2              11320          11320         11320                 11320
# 3              12022          12022         12022                 12022
# 4              11939          11939         11939                 11939
# 5              12323          12323         12323                 12323
#
#        Latitude  Longitude
# Month
# 1         12420      12420
# 2         11320      11320
# 3         12022      12022
# 4         11939      11939
# 5         12323      12323

# %%
number_crimes = number_crimes [["Incident Description"]]
number_crimes.head()
# Out:
#        Incident Description
# Month
# 1                     12420
# 2                     11320
# 3                     12022
# 4                     11939
# 5                     12323

# %%
no_of_crimes = number_crimes.rename(columns={'Incident Description': 'Number of Incidents'})
no_of_crimes=no_of_crimes.reset_index()
no_of_crimes
# Out:
#    Month  Number of Incidents
# 0      1                12420
# 1      2                11320
# 2      3                12022
# 3      4                11939
# 4      5                12323
# 5      6                11755
# 6      7                13023
# 7      8                12720
# 8      9                 8391

# %%
import calendar
no_of_crimes['Month'] = no_of_crimes['Month'].apply(lambda x: calendar.month_abbr[x])
no_of_crimes["id"] = no_of_crimes.index + 1
no_of_crimes
# Out:
#   Month  Number of Incidents  id
# 0   Jan                12420   1
# 1   Feb                11320   2
# 2   Mar                12022   3
# 3   Apr                11939   4
# 4   May                12323   5
# 5   Jun                11755   6
# 6   Jul                13023   7
# 7   Aug                12720   8
# 8   Sep                 8391   9

# %% [markdown]
# ## Price vs. Popularity of the Listing (number of reviews)

# %%
price_pop_hood = new_list_df[['Neighborhood', 'Number of Reviews', 'Price']]

price_pop_hood.head()
# Out:
#        Neighborhood  Number of Reviews  Price
# 0  Western Addition                156    170
# 1    Bernal Heights                112    235
# 2    Haight Ashbury                 17     65
# 3    Haight Ashbury                  7     65
# 4  Western Addition                 27    675

# %%
new_price_pop_hood = price_pop_hood.groupby(['Neighborhood'])
new_pop_vs_price = new_price_pop_hood.mean()

new_pop_vs_price_df = new_pop_vs_price.reset_index()
new_pop_vs_price_df['id'] = new_pop_vs_price_df.index + 1
new_pop_vs_price_df.head()
# Out:
#           Neighborhood  Number of Reviews       Price  id
# 0              Bayview          53.508333  134.033333   1
# 1       Bernal Heights          51.253482  175.089136   2
# 2  Castro/Upper Market          50.289340  251.606599   3
# 3            Chinatown           5.608696  185.773913   4
# 4       Crocker Amazon          45.421053  154.210526   5

# %%
connection_string = "root:password@localhost/etl"
engine = create_engine(f'mysql://{connection_string}')

# %%
price_vs_crimes_df.to_sql(name='price_vs_crimes', con=engine, if_exists='append', index=False)

# %%
new_pop_vs_price_df.to_sql(name='new_pop_vs_price', con=engine, if_exists='append', index=False)

# %%
no_of_crimes.to_sql(name='no_of_crimes', con=engine, if_exists='append', index=False)

# %%
price_vs_room_df.to_sql(name='price_vs_room', con=engine, if_exists='append', index=False)

# %%
price_vs_neighborhood_df.to_sql(name='price_vs_neighborhood', con=engine, if_exists='append', index=False)

# %%
df_crime.to_sql(name='df_crime', con=engine, if_exists='append', index=False)

# %%
engine.table_names()
# Out:
# ['df_crime',
#  'new_pop_vs_price',
#  'no_of_crimes',
#  'price_vs_crimes',
#  'price_vs_neighborhood',
#  'price_vs_room']

# %%
pd.read_sql_query('select * from df_crime', con=engine).head()
# Out:
#                       Incident Description                    Neighborhood  \
# 0  ATM-related Crime (secondary code only)                       Chinatown
# 1  ATM-related Crime (secondary code only)  Financial District/South Beach
# 2  ATM-related Crime (secondary code only)               Lone Mountain/USF
# 3  ATM-related Crime (secondary code only)                          Marina
# 4  ATM-related Crime (secondary code only)                     Mission Bay
#
#    Number of Crimes  id
# 0                 2   1
# 1                 2   2
# 2                 1   3
# 3                 1   4
# 4                 1   5

# %%
pd.read_sql_query('select * from new_pop_vs_price', con=engine).head()
# Out:
#           Neighborhood  Number of Reviews       Price  id
# 0              Bayview          53.508333  134.033333   1
# 1       Bernal Heights          51.253482  175.089136   2
# 2  Castro/Upper Market          50.289340  251.606599   3
# 3            Chinatown           5.608696  185.773913   4
# 4       Crocker Amazon          45.421053  154.210526   5

# %%
pd.read_sql_query('select * from no_of_crimes', con=engine).head()
# Out:
#   Month  Number of Incidents  id
# 0   Jan                12420   1
# 1   Feb                11320   2
# 2   Mar                12022   3
# 3   Apr                11939   4
# 4   May                12323   5

# %%
pd.read_sql_query('select * from price_vs_crimes', con=engine).head()
# Out:
#           Neighborhood  Number of Crimes  Price  id
# 0       Bernal Heights            1819.0  142.0   1
# 1  Castro/Upper Market            3352.0  180.0   2
# 2            Chinatown            2069.0  140.0   3
# 3            Excelsior            1807.0  100.0   4
# 4            Glen Park             524.0  174.0   5

# %%
pd.read_sql_query('select * from price_vs_neighborhood', con=engine).head()
# Out:
#      Neighborhood        Room Type       Price  Number of Reviews  id
# 0         Bayview  Entire home/apt  161.660000          49.540000   1
# 1         Bayview     Private room  115.202899          55.826087   2
# 2         Bayview      Shared room   52.000000          92.000000   3
# 3  Bernal Heights  Entire home/apt  215.365639          42.942731   4
# 4  Bernal Heights     Private room  106.030534          65.641221   5

# %%
pd.read_sql_query('select * from price_vs_room', con=engine).head()
# Out:
#          Room Type       Price  Number of Reviews  id
# 0  Entire home/apt  268.743564          36.248864   1
# 1     Private room  132.618136          53.946755   2
# 2      Shared room   69.607362          44.656442   3
